# %% [markdown]
# # *Introduction to Pandas*

# %% [markdown]
# ## What is pandas  ?
#
# *Pandas is a powerful Python library used for data analysis and data manipulation.
# It is mainly used to easily handle tabular data (rows and columns), such as data from Excel files, CSV files, and databases*

# %% [markdown]
# ## Installation of Pandas

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# *pip is used in Python to install, update, and remove libraries (packages).*

# %% [markdown]
# ##### **pip:** Package manager
# ##### **install:** To install a new package
# ##### **pandas:** Name of the library

# %% [markdown]
# ## Import Pandas library

# %%
import pandas as pd

# %% [markdown]
# ##### **import:** A keyword used to bring a library or module into Python
# ##### **pandas:** A Python library used for data analysis and data handling
# ##### **as:** Means alias (a short name)
# ##### **pd:** A short form (alias) for pandas

# %% [markdown]
# ## Data structures
# ##### **Series :-** *1-D data (single column)*
# ##### **DataFrame :-** *2-D data (rows + columns)*

# %% [markdown]
#  **Series:** A Series is like a single column that contains values along with their index.
#
# ### Simple Series

# %%
data = [10, 20, 30, 40]
j = pd.Series(data)
print(j)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %% [markdown]
# ### Custom Index ke saath Series

# %%
data= [10,20,30,40,50]                     
a= pd.Series(data, index = ['a','b','c','d','e'])
print(a)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %% [markdown]
# ### Dictionary se Series

# %%
data = {"Math": 85, "Science": 90, "English": 78}
j = pd.Series(data)
print(j)
# Out:
# Math       85
# Science    90
# English    78
# dtype: int64

# %% [markdown]
# ## operations
# #### Arithmetic Operations(add,Subtract,Multiply)
# #### Series vs Series Operations
# #### Built-in Functions (Stats)
# #### modify karna

# %%
a = pd.Series([10, 20, 30])
print(a + 5)
# Out:
# 0    15
# 1    25
# 2    35
# dtype: int64

# %%
a = pd.Series([10, 20, 30])
print(a - 5)
# Out:
# 0     5
# 1    15
# 2    25
# dtype: int64

# %%
a = pd.Series([10, 20, 30])
print(a * 5)
# Out:
# 0     50
# 1    100
# 2    150
# dtype: int64

# %% [markdown]
# ### Series vs Series Operations

# %%
s1 = pd.Series([10, 20, 30])
s2 = pd.Series([1, 2, 3])
print(s1 + s2)
# Out:
# 0    11
# 1    22
# 2    33
# dtype: int64

# %% [markdown]
# ### Comparison Operations

# %%
data = [10, 20, 30, 40]
s = pd.Series(data)
print(s)
print(s > 15)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64
# 0    False
# 1     True
# 2     True
# 3     True
# dtype: bool

# %% [markdown]
# ### Built-in Functions

# %%
data= [10,20,30,40,50]                     
a= pd.Series(data, index = ['a','b','c','d','e'])
print(a)
print(a.sum())    # total
print(a.mean())   # average
print(a.max())    # maximum
print(a.min())    # minimum
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64
# 150
# 30.0
# 50
# 10

# %% [markdown]
# ### modify karna

# %%
s = pd.Series([10, 20, 30], index=["a", "b", "c"])
s['b']= 200
print(s)
# Out:
# a     10
# b    200
# c     30
# dtype: int64

# %% [markdown]
# ### DataFrame
#
# **DataFrame:** *A DataFrame is like a table or an Excel sheet that contains rows and columns, and each column has a name.*

# %%
import numpy as np

# %% [markdown]
# **import numpy as np:** The NumPy library is used in the program because **np.nan** is used.
# **np.nan** means a missing value or an empty value.

# %%
data = {
    "Name": ["Jatin", "aman", "Neha","ayush","abhi","aman","varun"],
    "Age": [22, 24, 21, np.nan, 25, 24, 20 ],
    "Marks": [85, 90, np.nan, 82, 91, 90,83]
}
df = pd.DataFrame(data)
print(df)
# Out:
#     Name   Age  Marks
# 0  Jatin  22.0   85.0
# 1   aman  24.0   90.0
# 2   Neha  21.0    NaN
# 3  ayush   NaN   82.0
# 4   abhi  25.0   91.0
# 5   aman  24.0   90.0
# 6  varun  20.0   83.0

# %% [markdown]
# Ek variable me dictionary {} ke form me data store kiya , Us dictionary ko **pd.DataFrame()** me pass karke pandas DataFrame banya.,pandas automatic index karaga

# %%
df['rollno']=[101,102,103,104,105,102,107]         
print(df)
# Out:
#     Name   Age  Marks  rollno
# 0  Jatin  22.0   85.0     101
# 1   aman  24.0   90.0     102
# 2   Neha  21.0    NaN     103
# 3  ayush   NaN   82.0     104
# 4   abhi  25.0   91.0     105
# 5   aman  24.0   90.0     102
# 6  varun  20.0   83.0     107

# %% [markdown]
# To add a new column to an existing DataFrame, we use
# **df["new_column"] = value**.

# %%
df.head()
# Out:
#     Name   Age  Marks  rollno
# 0  Jatin  22.0   85.0     101
# 1   aman  24.0   90.0     102
# 2   Neha  21.0    NaN     103
# 3  ayush   NaN   82.0     104
# 4   abhi  25.0   91.0     105

# %% [markdown]
# **df.head():** It shows the first 5 rows of the data.

# %%
df.tail()
# Out:
#     Name   Age  Marks  rollno
# 2   Neha  21.0    NaN     103
# 3  ayush   NaN   82.0     104
# 4   abhi  25.0   91.0     105
# 5   aman  24.0   90.0     102
# 6  varun  20.0   83.0     107

# %% [markdown]
# **df.tail:-** Ye data ke last (aakhri) 5 rows ko show karta hai.

# %%
df.sample()
# Out:
#     Name   Age  Marks  rollno
# 6  varun  20.0   83.0     107

# %% [markdown]
# **df.sample():** It shows one random row from the data.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
#  1   Age     6 non-null      float64
#  2   Marks   6 non-null      float64
#  3   rollno  7 non-null      int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 356.0+ bytes

# %% [markdown]
# **df.info():** It shows information about the data types of the data.

# %%
df.isnull()
# Out:
#     Name    Age  Marks  rollno
# 0  False  False  False   False
# 1  False  False  False   False
# 2  False  False   True   False
# 3  False   True  False   False
# 4  False  False  False   False
# 5  False  False  False   False
# 6  False  False  False   False

# %% [markdown]
# **df.isnull():** It shows missing values as `True` and filled (non-missing) values as `False` in the data.

# %%
df.isnull().sum()
# Out:
# Name      0
# Age       1
# Marks     1
# rollno    0
# dtype: int64

# %% [markdown]
# **df.isnull().sum():** It shows the number of missing values in each column.

# %%
# df.fillna(method=("ffill"),inplace=True)

# %% [markdown]
# **df.fillna:** It is used to fill missing data.

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# dtype: bool

# %% [markdown]
# **df.duplicated():** It shows duplicate data as `True` and the remaining (unique) data as `False`.

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %% [markdown]
# **df.duplicated().sum():** It is used to get the total count of duplicate rows in the DataFrame.

# %%
df.drop_duplicates(inplace= True)

# %% [markdown]
# **df.drop_duplicates(inplace=True):** It is used to delete duplicate rows from the data.

# %%
print(df.describe())
# Out:
#              Age      Marks      rollno
# count   5.000000   5.000000    6.000000
# mean   22.400000  86.200000  103.666667
# std     2.073644   4.086563    2.160247
# min    20.000000  82.000000  101.000000
# 25%    21.000000  83.000000  102.250000
# 50%    22.000000  85.000000  103.500000
# 75%    24.000000  90.000000  104.750000
# max    25.000000  91.000000  107.000000

# %% [markdown]
# **print(df.describe()):** It is used to show summary statistics of the numeric columns in a DataFrame, such as count, mean, standard deviation (std), minimum (min), 25%, 50%, 75% percentiles, and maximum (max).

# %%
df.nunique()
# Out:
# Name      6
# Age       5
# Marks     5
# rollno    6
# dtype: int64

# %% [markdown]
# **df.nunique():** It is used to get the count of unique (distinct) values in each column.

# %%
df['rollno']=pd.to_datetime(df['rollno'],errors="coerce")

# %% [markdown]
# **pd.to_datetime:** It is used to convert the `'rollno'` column to datetime format, and if any value cannot be converted, it is assigned as `NaT` (Not a Time).

# %% [markdown]
# ## upload csv file

# %%
a=pd.read_csv("netflix_titles.csv")
a.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# **Read a CSV file:-** To read a CSV file into a pandas DataFrame, we use pd.read_csv().
# Replace **filename.csv** with the exact path or name of your file.

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
a.columns = a.columns.str.strip()

# %%
a.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
a['date_added']=pd.to_datetime(a['date_added'],errors="coerce")

# %%
duration_split = a['duration'].str.extract(r'(\d+)\s*(\w+)')            ## Regular expressions (regex) are a powerful tool for extracting specific patterns from text data.
a['duration_num'] = pd.to_numeric(duration_split[0],errors ='coerce')
a['duration_unit']=duration_split[1]

# %%
a.isnull().sum()
# Out:
# show_id             0
# type                0
# title               0
# director         2634
# cast              825
# country           831
# date_added         98
# release_year        0
# rating              4
# duration            3
# listed_in           0
# description         0
# duration_num        3
# duration_unit       3
# dtype: int64

# %%
a['duration_unit'].value_counts()
# Out:
# duration_unit
# min        6128
# Season     1793
# Seasons     883
# Name: count, dtype: int64

# %%
a['duration_unit'] = a['duration_unit'].replace({'Seasons': 'Season'})

# %%
a['duration_unit'].value_counts()
# Out:
# duration_unit
# min       6128
# Season    2676
# Name: count, dtype: int64

# %%
a['duration_num'] = a.groupby('duration_unit')['duration_num'].transform(lambda x: x.fillna(x.median()))   #missingnvalue (nan) ko fill karna

# %%
# df.groupby('duration_unit') --> sab rows ko unke duration_unit ke hisaab se group karo. season group, min group
#  ['duration_num'] -- means group ke andar sirf number column.
# The transform() function in pandas is a powerful tool that allows you to apply a function to each element of a DataFrame or Series,
# returning a result with the same shape as the original data. 
# This is particularly useful when you need to apply a transformation function 
# that returns a result for each element while maintaining the structure (rows and indexes) of the original DataFrame.
###############################################################################################

# import pandas as pd

# t = pd.DataFrame({'A': [1, 2, 3, 4], 'B': [5, 6, 7, 8]})
# t['A_transformed'] = t['A'].transform(lambda x: x * 2)
# t['B_transformed'] = t['B'].transform(lambda x: x * 2)
# print(t)

# %%
a.loc[a['duration'].isna() & (a['type'] == 'Movies'),'duration_unit '] ='min'
# Jitni rows me duration missing (NaN) hai, Aur type = Movie hai Un rows ke duration_unit me 'min' fill kar do
a.loc[a['duration'].isna() & (a['type'] == 'TV Show'),'duration_unit '] ='season'

# loc[] = label-based selection -> Rows ko condition se select karta hai, Aur un rows me kisi column ki value change ya read kar sakte ho.
# df.loc[df['age'] > 18, 'status'] = 'Adult'
# isna() = checks missing values (NaN, empty) -> give result in True or False

# %%
a.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %%
a = a.drop(columns=['duration'])

# %%
a.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#      date_added  release_year rating  \
# 8802 2019-11-20          2007      R
# 8803 2019-07-01          2018  TV-Y7
# 8804 2019-11-01          2009      R
# 8805 2020-01-11          2006     PG
# ...

# %%
# # # # # # Option A — Fill missing with "Unknown"
# # # # # df['rating'] = df['rating'].fillna('Unknown')
# # # # Option B — Fill missing with mode (most common rating)
# # # most_common = df['rating'].mode()[0]
# # # df['rating'] = df['rating'].fillna(most_common)
# # Option C — Create a “missing flag” + fill (BEST for ML)
# df['rating_missing'] = df['rating'].isna().astype(int)
# df['rating'] = df['rating'].fillna('Unknown')

# %%
a['rating_missing'] = a['rating'].isna().astype(int)  # True-1 , False-0
a['rating'] = a['rating'].fillna('Unknown')

# df['rating_missing'] = df['rating'].isna().astype(int) , # True-1 , False-0
# df['rating'] = df['rating'].fillna('Unknown')

# %%
a.isnull().sum()
# Out:
# show_id              0
# type                 0
# title                0
# director          2634
# cast               825
# country            831
# date_added          98
# release_year         0
# rating               0
# listed_in            0
# description          0
# duration_num         3
# duration_unit        3
# duration_unit     8807
# rating_missing       0
# dtype: int64

# %%
a.duplicated().sum()
# Out:
# np.int64(0)

# %%
median_date = a['date_added'].median()
a['date_added'] =a['date_added'].fillna(median_date)

# %%
a.isnull().sum()
# Out:
# show_id              0
# type                 0
# title                0
# director          2634
# cast               825
# country            831
# date_added           0
# release_year         0
# rating               0
# listed_in            0
# description          0
# duration_num         3
# duration_unit        3
# duration_unit     8807
# rating_missing       0
# dtype: int64

# %%
a['country_missing'] = a['country'].isna().astype(int)
a['country'] = a['country'].fillna("Unknown")

# %%
a.isnull().sum()
# Out:
# show_id               0
# type                  0
# title                 0
# director           2634
# cast                825
# country               0
# date_added            0
# release_year          0
# rating                0
# listed_in             0
# description           0
# duration_num          3
# duration_unit         3
# duration_unit      8807
# rating_missing        0
# country_missing       0
# dtype: int64

# %%
a['director_missing'] = a['director'].isna().astype(int)  # True - 1 , False - 0
a['cast_missing'] = a['cast'].isna().astype(int)

# %%
a['director'] = a['director'].fillna("Unknown")
a['cast'] = a['cast'].fillna("Unknown")
a['duration_unit'] = a['duration_unit'].fillna("Unknown")

# %%
a['duration_num'] = a['duration_num'].fillna("Unknown")

# %%
a.isnull().sum()
# Out:
# show_id                0
# type                   0
# title                  0
# director               0
# cast                   0
# country                0
# date_added             0
# release_year           0
# rating                 0
# listed_in              0
# description            0
# duration_num           0
# duration_unit          0
# duration_unit       8807
# rating_missing         0
# country_missing        0
# director_missing       0
# cast_missing           0
# dtype: int64

# %%
# a['duration_num'] = a.groupby('duration_unit')['duration_num'].transform(lambda x: x.fillna(x.median()))

# %%
a.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          Unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          Unknown
# 4      s5  TV Show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                            Unknown        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating  \
# 0 2021-09-25          2020  PG-13
# 1 2021-09-24          2021  TV-MA
# 2 2021-09-24          2021  TV-MA
# 3 2021-09-24          2021  TV-MA
# ...

# %%
a.to_csv("cleaned_netflix.csv",index= False)

# %% [markdown]
# * **a:** A DataFrame in pandas that stores your data in table form. This will contain your cleaned or processed data.
# * **to_csv():** A pandas function used to save a DataFrame as a CSV file.
# * **"cleaned_netflix.csv":** The name of the CSV file. A new CSV file with this name will be created. If a file with the same name already exists, it will be overwritten.
# * **index=False:** By default, pandas saves the DataFrame’s index (0, 1, 2, …) in the file. `index=False` means do **not** save the index in the CSV file.

# %% [markdown]
# ## Try these 4 question

# %% [markdown]
# * Pandas use karke ek DataFrame banao jisme ye data ho: hint :- pd.DataFrame()
#     * Name,Age,Marks.
# * DataFrame me:
#    * missing value (NaN) ko Age ka mean se fill karo hint :-isna() / fillna()
#    * sirf un students ko print karo jinke Marks ≥ 85 hint :-conditional filtering
# * Ek naya column banao:
#   * Result → agar Marks ≥ 80 ho to "Pass" warna "Fail" hint:- np.where() ya apply()
# * DataFrame ko Marks ke descending order me sort karo. hint:-dataFrame ko Marks ke descending order me shint
