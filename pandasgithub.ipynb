# %% [markdown]
# # *Introduction to Pandas*

# %% [markdown]
# ## What is pandas  ?
# *Pandas Python ki ek powerful library hai jo data analysis aur data manipulation ke liye use hoti hai.
# Pandas ka use tables (rows & columns) wale data ko easily handle karne ke liye hota hai, jaise Excel, CSV, database data.*

# %% [markdown]
# ## Installation of Pandas

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\hp\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# *pip ka use Python me libraries install, update aur remove karne ke liye hota hai.*

# %% [markdown]
# ##### *pip :- package manager*
# ##### *install :- naya package install karna*
# ##### *pandas :- library ka naam*

# %% [markdown]
# ## Import Pandas library

# %%
import pandas as pd

# %% [markdown]
# ##### **import:-** *keyword ka use library ya module ko Python me lane ke liye hota hai*
# ##### **pandas:-** *ek Python library hai jo data analysis & data handling ke kaam aati hai*
# ##### **as:-** *ka matlab hota hai alias (short name)*
# ##### **pd:-** *ek short form hai pandas ke liye*

# %% [markdown]
# ## Data structures
# ##### **Series :-** *1-D data (single column)*
# ##### **DataFrame :-** *2-D data (rows + columns)*

# %% [markdown]
# **Series:-** *Series ek single column jaisi hoti hai jisme Values hoti hain ,Unke saath index hota hai*
# ### Simple Series

# %%
data = [10, 20, 30, 40]
j = pd.Series(data)
print(j)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %% [markdown]
# ### Custom Index ke saath Series

# %%
data= [10,20,30,40,50]                     
a= pd.Series(data, index = ['a','b','c','d','e'])
print(a)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %% [markdown]
# ### Dictionary se Series

# %%
data = {"Math": 85, "Science": 90, "English": 78}
j = pd.Series(data)
print(j)
# Out:
# Math       85
# Science    90
# English    78
# dtype: int64

# %% [markdown]
# ## operations
# #### Arithmetic Operations(add,Subtract,Multiply)
# #### Series vs Series Operations
# #### Built-in Functions (Stats)
# #### modify karna

# %%
a = pd.Series([10, 20, 30])
print(a + 5)
# Out:
# 0    15
# 1    25
# 2    35
# dtype: int64

# %%
a = pd.Series([10, 20, 30])
print(a - 5)
# Out:
# 0     5
# 1    15
# 2    25
# dtype: int64

# %%
a = pd.Series([10, 20, 30])
print(a * 5)
# Out:
# 0     50
# 1    100
# 2    150
# dtype: int64

# %% [markdown]
# ### Series vs Series Operations

# %%
s1 = pd.Series([10, 20, 30])
s2 = pd.Series([1, 2, 3])
print(s1 + s2)
# Out:
# 0    11
# 1    22
# 2    33
# dtype: int64

# %% [markdown]
# ### Comparison Operations

# %%
data = [10, 20, 30, 40]
s = pd.Series(data)
print(s)
print(s > 15)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64
# 0    False
# 1     True
# 2     True
# 3     True
# dtype: bool

# %% [markdown]
# ### Built-in Functions

# %%
data= [10,20,30,40,50]                     
a= pd.Series(data, index = ['a','b','c','d','e'])
print(a)
print(a.sum())    # total
print(a.mean())   # average
print(a.max())    # maximum
print(a.min())    # minimum
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64
# 150
# 30.0
# 50
# 10

# %% [markdown]
# ### modify karna

# %%
s = pd.Series([10, 20, 30], index=["a", "b", "c"])
s['b']= 200
print(s)
# Out:
# a     10
# b    200
# c     30
# dtype: int64

# %% [markdown]
# ### DataFrame
# **Data frame:-** *DataFrame ek table / Excel sheet jaisa hota hai, jisme Rows or Columns hoti hain ,Har column ka name hota hai*

# %%
import numpy as np

# %% [markdown]
# **import numpy as np :-** *program me numpy library isliye use ki gayi hai kyunki* **np.nan** *ka use kiya gaya hai.* **np.nan** *ka matlab hota hai missing value / empty value.*

# %%
data = {
    "Name": ["Jatin", "aman", "Neha","ayush","abhi","aman","varun"],
    "Age": [22, 24, 21, np.nan, 25, 24, 20 ],
    "Marks": [85, 90, np.nan, 82, 91, 90,83]
}
df = pd.DataFrame(data)
print(df)
# Out:
#     Name   Age  Marks
# 0  Jatin  22.0   85.0
# 1   aman  24.0   90.0
# 2   Neha  21.0    NaN
# 3  ayush   NaN   82.0
# 4   abhi  25.0   91.0
# 5   aman  24.0   90.0
# 6  varun  20.0   83.0

# %% [markdown]
# Ek variable me dictionary {} ke form me data store kiya , Us dictionary ko **pd.DataFrame()** me pass karke pandas DataFrame banya.,pandas automatic index karaga

# %%
df['rollno']=[101,102,103,104,105,102,107]         
print(df)
# Out:
#     Name   Age  Marks  rollno
# 0  Jatin  22.0   85.0     101
# 1   aman  24.0   90.0     102
# 2   Neha  21.0    NaN     103
# 3  ayush   NaN   82.0     104
# 4   abhi  25.0   91.0     105
# 5   aman  24.0   90.0     102
# 6  varun  20.0   83.0     107

# %% [markdown]
# *Existing DataFrame me naya column add karne ke liye* **df["new_column"] = value** *ka use karte hain*

# %%
print(df['Name'])
# Out:
# 0    Jatin
# 1     aman
# 2     Neha
# 3    ayush
# 4     abhi
# 5     aman
# 6    varun
# Name: Name, dtype: object

# %% [markdown]
# *DataFrame me sirf ek column dekhne ke liye hum* **df["column_name"]**

# %%
df.head()
# Out:
#     Name   Age  Marks  rollno
# 0  Jatin  22.0   85.0     101
# 1   aman  24.0   90.0     102
# 2   Neha  21.0    NaN     103
# 3  ayush   NaN   82.0     104
# 4   abhi  25.0   91.0     105

# %% [markdown]
# **df.head():-** *Ye data ke pehle 5 rows ko show karta hai.*

# %%
df.tail()
# Out:
#     Name   Age  Marks  rollno
# 2   Neha  21.0    NaN     103
# 3  ayush   NaN   82.0     104
# 4   abhi  25.0   91.0     105
# 5   aman  24.0   90.0     102
# 6  varun  20.0   83.0     107

# %% [markdown]
# **df.tail:-** *Ye data ke last (aakhri) 5 rows ko show karta hai.*

# %%
df.sample()
# Out:
#     Name   Age  Marks  rollno
# 6  varun  20.0   83.0     107

# %% [markdown]
# **df.sample()** *Ye data me se ek random (koi bhi ek) row ko show karta hai.*

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
#  1   Age     6 non-null      float64
#  2   Marks   6 non-null      float64
#  3   rollno  7 non-null      int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 356.0+ bytes

# %% [markdown]
# **df.info():-** *Ye data ke data types ki information show karta hai.*

# %%
df.isnull()
# Out:
#     Name    Age  Marks  rollno
# 0  False  False  False   False
# 1  False  False  False   False
# 2  False  False   True   False
# 3  False   True  False   False
# 4  False  False  False   False
# 5  False  False  False   False
# 6  False  False  False   False

# %% [markdown]
# **df.isnull():-** *Ye data me missing values ko True aur filled values ko False ke form me show karta hai.*

# %%
df.isnull().sum()
# Out:
# Name      0
# Age       1
# Marks     1
# rollno    0
# dtype: int64

# %% [markdown]
# **df.isnull().sum():-** *Ye har column me kitni missing values hain, uski information show karta hai.*

# %%
# df.fillna(method=("ffill"),inplace=True)

# %% [markdown]
# **df.fillna:-** *Ye missing data ko fill karne ke liye use hota hai.*

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# dtype: bool

# %% [markdown]
# **df.duplicated():-** *Ye **duplicate data ko True** aur **baaki (unique) data ko False** ke form me show karta hai.

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %% [markdown]
# `**df.duplicated().sum():-** ka use **DataFrame me total duplicate rows ki count nikalne** ke liye hota hai.

# %%
df.drop_duplicates(inplace= True)

# %% [markdown]
# **df.drop_duplicates(inplace= True):-** Ye **data me se duplicate rows ko delete** karne ke liye use hota hai.

# %%
print(df.describe())
# Out:
#              Age      Marks      rollno
# count   5.000000   5.000000    6.000000
# mean   22.400000  86.200000  103.666667
# std     2.073644   4.086563    2.160247
# min    20.000000  82.000000  101.000000
# 25%    21.000000  83.000000  102.250000
# 50%    22.000000  85.000000  103.500000
# 75%    24.000000  90.000000  104.750000
# max    25.000000  91.000000  107.000000

# %% [markdown]
# **print(df.describe()):-** ka use DataFrame ke numeric columns ka summary statistics show karne ke liye hota hai, jaise count, mean, std, min, 25%, 50%, 75%, aur ma

# %%
df.nunique()
# Out:
# Name      6
# Age       5
# Marks     5
# rollno    6
# dtype: int64

# %% [markdown]
# **df.nunique():-**` ka use **har column me unique (alag) values ki count** nikalne ke liye hota hai.

# %%
df['rollno']=pd.to_datetime(df['rollno'],errors="coerce")

# %% [markdown]
# **pd.to_datetime :-** ka use 'rollno' column ko datetime format me convert karne ke liye hota hai, aur agar koi value convert na ho paaye to NaT (Not a Time) assign ho jata hai.

# %% [markdown]
# ## upload csv file

# %%
a=pd.read_csv("netflix_titles.csv")
a.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %% [markdown]
# **CSV file ko read karo:-** CSV file ko pandas DataFrame mein read karne ke liye **pd.read_csv()** use karte hain:

# %% [markdown]
# **'filename.csv'** ki jagah aap apni file ka exact path ya file name dena.

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
a.columns = a.columns.str.strip()

# %%
a.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
a['date_added']=pd.to_datetime(a['date_added'],errors="coerce")

# %%
duration_split = a['duration'].str.extract(r'(\d+)\s*(\w+)')            ## Regular expressions (regex) are a powerful tool for extracting specific patterns from text data.
a['duration_num'] = pd.to_numeric(duration_split[0],errors ='coerce')
a['duration_unit']=duration_split[1]

# %%
a.isnull().sum()
# Out:
# show_id             0
# type                0
# title               0
# director         2634
# cast              825
# country           831
# date_added         98
# release_year        0
# rating              4
# duration            3
# listed_in           0
# description         0
# duration_num        3
# duration_unit       3
# dtype: int64

# %%
a['duration_unit'].value_counts()
# Out:
# duration_unit
# min        6128
# Season     1793
# Seasons     883
# Name: count, dtype: int64

# %%
a['duration_unit'] = a['duration_unit'].replace({'Seasons': 'Season'})

# %%
a['duration_unit'].value_counts()
# Out:
# duration_unit
# min       6128
# Season    2676
# Name: count, dtype: int64

# %%
a['duration_num'] = a.groupby('duration_unit')['duration_num'].transform(lambda x: x.fillna(x.median()))   #missingnvalue (nan) ko fill karna

# %%
# df.groupby('duration_unit') --> sab rows ko unke duration_unit ke hisaab se group karo. season group, min group
#  ['duration_num'] -- means group ke andar sirf number column.
# The transform() function in pandas is a powerful tool that allows you to apply a function to each element of a DataFrame or Series,
# returning a result with the same shape as the original data. 
# This is particularly useful when you need to apply a transformation function 
# that returns a result for each element while maintaining the structure (rows and indexes) of the original DataFrame.
###############################################################################################

# import pandas as pd

# t = pd.DataFrame({'A': [1, 2, 3, 4], 'B': [5, 6, 7, 8]})
# t['A_transformed'] = t['A'].transform(lambda x: x * 2)
# t['B_transformed'] = t['B'].transform(lambda x: x * 2)
# print(t)

# %%
a.loc[a['duration'].isna() & (a['type'] == 'Movies'),'duration_unit '] ='min'
# Jitni rows me duration missing (NaN) hai, Aur type = Movie hai Un rows ke duration_unit me 'min' fill kar do
a.loc[a['duration'].isna() & (a['type'] == 'TV Show'),'duration_unit '] ='season'

# loc[] = label-based selection -> Rows ko condition se select karta hai, Aur un rows me kisi column ki value change ya read kar sakte ho.
# df.loc[df['age'] > 18, 'status'] = 'Adult'
# isna() = checks missing values (NaN, empty) -> give result in True or False

# %%
a.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# 3 2021-09-24          2021  TV-MA   1 Season
# 4 2021-09-24          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description  duration_num  \
# 0  As her father nears the end of his life, filmm...          90.0
# 1  After crossing paths at a party, a Cape Town t...           2.0
# 2  To protect his family from a powerful drug lor...           1.0
# 3  Feuds, flirtations and toilet talk go down amo...           1.0
# 4  In a city of coaching centers known to train I...           2.0
#
#   duration_unit duration_unit
# 0           min            NaN
# 1        Season            NaN
# 2        Season            NaN
# 3        Season            NaN
# 4        Season            NaN

# %%
a = a.drop(columns=['duration'])

# %%
a.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#      date_added  release_year rating  \
# 8802 2019-11-20          2007      R
# 8803 2019-07-01          2018  TV-Y7
# 8804 2019-11-01          2009      R
# 8805 2020-01-11          2006     PG
# 8806 2019-03-02          2015  TV-14
#
#                                            listed_in  \
# 8802                  Cult Movies, Dramas, Thrillers
# 8803          Kids' TV, Korean TV Shows, TV Comedies
# 8804                         Comedies, Horror Movies
# 8805              Children & Family Movies, Comedies
# 8806  Dramas, International Movies, Music & Musicals
#
#                                             description  duration_num  \
# 8802  A political cartoonist, a crime reporter and a...         158.0
# 8803  While living alone in a spooky town, a young g...           2.0
# 8804  Looking to survive in a world taken over by zo...          88.0
# 8805  Dragged from civilian life, a former superhero...          88.0
# 8806  A scrappy but poor boy worms his way into a ty...         111.0
#
#      duration_unit duration_unit
# 8802           min            NaN
# 8803        Season            NaN
# 8804           min            NaN
# 8805           min            NaN
# 8806           min            NaN

# %%
# # # # # # Option A — Fill missing with "Unknown"
# # # # # df['rating'] = df['rating'].fillna('Unknown')
# # # # Option B — Fill missing with mode (most common rating)
# # # most_common = df['rating'].mode()[0]
# # # df['rating'] = df['rating'].fillna(most_common)
# # Option C — Create a “missing flag” + fill (BEST for ML)
# df['rating_missing'] = df['rating'].isna().astype(int)
# df['rating'] = df['rating'].fillna('Unknown')

# %%
a['rating_missing'] = a['rating'].isna().astype(int)  # True-1 , False-0
a['rating'] = a['rating'].fillna('Unknown')

# df['rating_missing'] = df['rating'].isna().astype(int) , # True-1 , False-0
# df['rating'] = df['rating'].fillna('Unknown')

# %%
a.isnull().sum()
# Out:
# show_id              0
# type                 0
# title                0
# director          2634
# cast               825
# country            831
# date_added          98
# release_year         0
# rating               0
# listed_in            0
# description          0
# duration_num         3
# duration_unit        3
# duration_unit     8807
# rating_missing       0
# dtype: int64

# %%
a.duplicated().sum()
# Out:
# np.int64(0)

# %%
median_date = a['date_added'].median()
a['date_added'] =a['date_added'].fillna(median_date)

# %%
a.isnull().sum()
# Out:
# show_id              0
# type                 0
# title                0
# director          2634
# cast               825
# country            831
# date_added           0
# release_year         0
# rating               0
# listed_in            0
# description          0
# duration_num         3
# duration_unit        3
# duration_unit     8807
# rating_missing       0
# dtype: int64

# %%
a['country_missing'] = a['country'].isna().astype(int)
a['country'] = a['country'].fillna("Unknown")

# %%
a.isnull().sum()
# Out:
# show_id               0
# type                  0
# title                 0
# director           2634
# cast                825
# country               0
# date_added            0
# release_year          0
# rating                0
# listed_in             0
# description           0
# duration_num          3
# duration_unit         3
# duration_unit      8807
# rating_missing        0
# country_missing       0
# dtype: int64

# %%
a['director_missing'] = a['director'].isna().astype(int)  # True - 1 , False - 0
a['cast_missing'] = a['cast'].isna().astype(int)

# %%
a['director'] = a['director'].fillna("Unknown")
a['cast'] = a['cast'].fillna("Unknown")
a['duration_unit'] = a['duration_unit'].fillna("Unknown")

# %%
a['duration_num'] = a['duration_num'].fillna("Unknown")

# %%
a.isnull().sum()
# Out:
# show_id                0
# type                   0
# title                  0
# director               0
# cast                   0
# country                0
# date_added             0
# release_year           0
# rating                 0
# listed_in              0
# description            0
# duration_num           0
# duration_unit          0
# duration_unit       8807
# rating_missing         0
# country_missing        0
# director_missing       0
# cast_missing           0
# dtype: int64

# %%
# a['duration_num'] = a.groupby('duration_unit')['duration_num'].transform(lambda x: x.fillna(x.median()))

# %%
a.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          Unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          Unknown
# 4      s5  TV Show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                            Unknown        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating  \
# 0 2021-09-25          2020  PG-13
# 1 2021-09-24          2021  TV-MA
# 2 2021-09-24          2021  TV-MA
# 3 2021-09-24          2021  TV-MA
# 4 2021-09-24          2021  TV-MA
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description duration_num  \
# 0  As her father nears the end of his life, filmm...         90.0
# 1  After crossing paths at a party, a Cape Town t...          2.0
# 2  To protect his family from a powerful drug lor...          1.0
# 3  Feuds, flirtations and toilet talk go down amo...          1.0
# 4  In a city of coaching centers known to train I...          2.0
#
#   duration_unit duration_unit   rating_missing  country_missing  \
# 0           min            NaN               0                0
# 1        Season            NaN               0                0
# 2        Season            NaN               0                1
# 3        Season            NaN               0                1
# 4        Season            NaN               0                0
#
#    director_missing  cast_missing
# 0                 0             1
# 1                 1             0
# 2                 0             0
# 3                 1             1
# 4                 1             0

# %%
a.to_csv("cleaned_netflix.csv",index= False)

# %% [markdown]
# **a:-** ek DataFrame hai (jo pandas mein data ko table form mein store karta hai) Isme aapka cleaned / processed data hoga

# %% [markdown]
# **to_csv():-** pandas ka function hai.Iska use DataFrame ko CSV file mein save karne ke liye hota hai

# %% [markdown]
# **"cleaned_netflix.csv":-** Ye file ka naam hai. Is naam se ek nayi CSV file create hogi.Agar same naam ki file pehle se hogi, to wo overwrite ho jaayegi

# %% [markdown]
# **index=False:-** By default pandas DataFrame ka index (0,1,2,3…) bhi file mein save kar deta hai.index=False ka matlab.index ko CSV file mein save mat karo

# %% [markdown]
# ## Try these 4 question

# %% [markdown]
# * Pandas use karke ek DataFrame banao jisme ye data ho: **hint  :- pd.DataFrame()**
#    * Name,Age,Marks.
# * DataFrame me:
#    * missing value (NaN) ko Age ka mean se fill karo  **hint :-isna() / fillna()**
#    * sirf un students ko print karo jinke Marks ≥ 85  **hint :-conditional filtering**
# * Ek naya column banao:
#    * Result → agar Marks ≥ 80 ho to "Pass" warna "Fail" **hint:- np.where() ya apply()**
# * DataFrame ko Marks ke descending order me sort karo. **hint:-dataFrame ko Marks ke descending order me shint**
